# %% [markdown]
# # TME3: How Much Did It Rain? II
#
# https://www.kaggle.com/c/how-much-did-it-rain-ii
#
#
# Car cancellation guide:
# https://github.com/numb3r33/Kaggle-Competitions/blob/master/cars-cancellation/cars_cancellation.ipynb
#
#
# En pluviométrie, pour mesurer les hauteurs des précipitations on utilise des jauges qui receuillent la pluie. On est alors capable de déterminer la quantité d'eau tombée durant un intervalle de temps donné, ici une heure.
# Cependant, les jauges ne peuvent pas couvrir l'ensemble des lieux que l'on souhaite observer. On utilise alors des radars et on estime la hauteur des précipitations à partir de leurs relevés.
# Cependant, ces estimations correspondent mal aux mesures effectués sur les jauges.
# L'objectif de ce challenge est de fournir un meilleur estimateur basée sur les relevés des radars.

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
#import seaborn as sb
# %matplotlib inline  

from sklearn import linear_model
from sklearn import cross_validation
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# # Chargement des données
#
# Les données sont des séquences de relevés de capteurs sur une durée d'une heure à des temps variables.
# A chaque séquence est associée un identifiant et la distance du capteur à une jauge dont il faut prédire les mesures à la fin de l'heure.
# Un élément de la séquence contient les différentes mesures effectués par le radar à un instant donné.

# %%
# %%time
dfTrain = pd.read_csv('./data/train_nnull.csv')
dfTrain['Id_index'] = dfTrain['Id']
dfTrain = dfTrain.set_index('Id_index')
# Out:
# CPU times: user 15.7 s, sys: 1.3 s, total: 17 s
# Wall time: 23.1 s

# %%
dfTest = pd.read_csv('./data/test.csv')
dfTest = dfTest.set_index('Id')

# %% [markdown]
# # Premier aperçu
#
# On commence par regarder succintement les données. On cherche à répondre à des questions d'ordre général sur les données:
# Nombre de séquences et nombre de relevés, nombre de dimension, il y a-t-il des dimensions catégorielles à traiter et y a-t-il des données manquantes?
#
# Un premier résumé permet de dire qu'il y a 13765201 entrées de 24 dimensions (23 si on exclu la quantité a prédire), toutes numériques.
# On voit aussi en extrayant la tête et la queue de la table qu'il y a un certain nombre de données manquantes et qu'il y a 1180945 séquences.

# %%
dfTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13765201 entries, 1 to 1180945
# Data columns (total 24 columns):
# Id                       int64
# minutes_past             int64
# radardist_km             float64
# Ref                      float64
# Ref_5x5_10th             float64
# Ref_5x5_50th             float64
# Ref_5x5_90th             float64
# RefComposite             float64
# RefComposite_5x5_10th    float64
# RefComposite_5x5_50th    float64
# RefComposite_5x5_90th    float64
# RhoHV                    float64
# RhoHV_5x5_10th           float64
# RhoHV_5x5_50th           float64
# RhoHV_5x5_90th           float64
# Zdr                      float64
# Zdr_5x5_10th             float64
# Zdr_5x5_50th             float64
# Zdr_5x5_90th             float64
# Kdp                      float64
# Kdp_5x5_10th             float64
# Kdp_5x5_50th             float64
# Kdp_5x5_90th             float64
# Expected                 float64
# dtypes: float64(22), int64(2)
# memory usage: 2.6 GB

# %%
dfTrain.head(10)
# Out:
#           Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  Ref_5x5_50th  \
# Id_index
# 1          1             3            10   NaN           NaN           NaN
# 1          1            16            10   NaN           NaN           NaN
# 1          1            25            10   NaN           NaN           NaN
# 1          1            35            10   NaN           NaN           NaN
# 1          1            45            10   NaN           NaN           NaN
# 1          1            55            10   NaN           NaN           NaN
# 2          2             1             2   9.0           5.0           7.5
# 2          2             6             2  26.5          22.5          25.5
# 2          2            11             2  21.5          15.5          20.5
# 2          2            16             2  18.0          14.0          17.5
#
#           Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  \
# Id_index
# 1                  NaN           NaN                    NaN
# 1                  NaN           NaN                    NaN
# 1                  NaN           NaN                    NaN
# 1                  NaN           NaN                    NaN
# 1                  NaN           NaN                    NaN
# 1                  NaN           NaN                    NaN
# 2                 10.5          15.0                   10.5
# 2                 31.5          26.5                   26.5
# 2                 25.0          26.5                   23.5
# 2                 21.0          20.5                   18.0
#
#           RefComposite_5x5_50th    ...     RhoHV_5x5_90th     Zdr  \
# Id_index                           ...
# 1                           NaN    ...                NaN     NaN
# 1                           NaN    ...                NaN     NaN
# 1                           NaN    ...                NaN     NaN
# 1                           NaN    ...                NaN     NaN
# 1                           NaN    ...                NaN     NaN
# 1                           NaN    ...                NaN     NaN
# 2                          16.5    ...           0.998333  0.3750
# 2                          28.5    ...           1.005000  0.0625
# 2                          25.0    ...           1.001667  0.3125
# 2                          20.5    ...           1.001667  0.2500
#
#           Zdr_5x5_10th  Zdr_5x5_50th  Zdr_5x5_90th       Kdp  Kdp_5x5_10th  \
# Id_index
# 1                  NaN           NaN           NaN       NaN           NaN
# 1                  NaN           NaN           NaN       NaN           NaN
# 1                  NaN           NaN           NaN       NaN           NaN
# 1                  NaN           NaN           NaN       NaN           NaN
# 1                  NaN           NaN           NaN       NaN           NaN
# 1                  NaN           NaN           NaN       NaN           NaN
# 2              -0.1250        0.3125        0.8750  1.059998     -1.410004
# 2              -0.1875        0.2500        0.6875       NaN           NaN
# 2              -0.0625        0.3125        0.6250  0.349991           NaN
# 2               0.1250        0.3750        0.6875  0.349991     -1.059998
#
#           Kdp_5x5_50th  Kdp_5x5_90th  Expected
# Id_index
# 1                  NaN           NaN     0.254
# 1                  NaN           NaN     0.254
# 1                  NaN           NaN     0.254
# 1                  NaN           NaN     0.254
# 1                  NaN           NaN     0.254
# 1                  NaN           NaN     0.254
# 2            -0.350006      1.059998     1.016
# 2                  NaN      1.409988     1.016
# 2            -0.350006      1.759994     1.016
# 2             0.000000      1.059998     1.016
#
# [10 rows x 24 columns]

# %%
dfTrain.tail(10)
# Out:
#                Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  \
# Id_index
# 1180945   1180945            14             9  33.5           NaN
# 1180945   1180945            19             9  43.5           9.5
# 1180945   1180945            24             9  31.5          19.5
# 1180945   1180945            28             9  24.0          25.5
# 1180945   1180945            33             9  25.5          22.0
# 1180945   1180945            38             9  33.0          19.5
# 1180945   1180945            42             9  33.0          21.0
# 1180945   1180945            47             9  29.5          10.0
# 1180945   1180945            52             9  19.0           NaN
# 1180945   1180945            57             9   7.5           NaN
#
#           Ref_5x5_50th  Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  \
# Id_index
# 1180945           32.5          46.5          35.5                    6.5
# 1180945           39.0          49.5          43.5                   15.5
# 1180945           31.5          41.0          31.5                   20.0
# 1180945           31.0          41.0          24.0                   25.5
# 1180945           27.0          31.0          29.0                   25.0
# 1180945           25.5          36.5          33.0                   20.5
# 1180945           30.5          37.0          36.5                   22.0
# 1180945           26.0          30.5          31.0                   16.5
# 1180945           15.5          26.5          19.0                    NaN
# 1180945           10.0          13.0          14.5                   10.0
#
#           RefComposite_5x5_50th    ...     RhoHV_5x5_90th   Zdr  Zdr_5x5_10th  \
# Id_index                           ...
# 1180945                    35.5    ...                NaN   NaN           NaN
# 1180945                    43.0    ...                NaN   NaN           NaN
# 1180945                    35.0    ...                NaN   NaN           NaN
# 1180945                    31.0    ...                NaN   NaN           NaN
# 1180945                    28.0    ...                NaN   NaN           NaN
# 1180945                    28.0    ...                NaN   NaN           NaN
# 1180945                    33.5    ...                NaN   NaN           NaN
# 1180945                    26.0    ...           1.051667  1.75           NaN
# 1180945                    16.5    ...           1.051667   NaN           NaN
# 1180945                    12.5    ...           1.051667  0.00        -1.125
#
#           Zdr_5x5_50th  Zdr_5x5_90th        Kdp  Kdp_5x5_10th  Kdp_5x5_50th  \
# Id_index
# 1180945            NaN           NaN        NaN           NaN           NaN
# 1180945            NaN           NaN        NaN           NaN           NaN
# 1180945            NaN           NaN        NaN           NaN           NaN
# 1180945            NaN           NaN        NaN           NaN           NaN
# 1180945            NaN           NaN        NaN           NaN           NaN
# 1180945            NaN           NaN        NaN           NaN           NaN
# 1180945            NaN           NaN        NaN           NaN           NaN
# 1180945          0.750        3.0000  13.379990           NaN           NaN
# 1180945            NaN        2.8125        NaN           NaN           NaN
# 1180945          0.375        3.2500   6.069992           NaN     -8.029999
#
#           Kdp_5x5_90th  Expected
# Id_index
# 1180945            NaN  8.636004
# 1180945            NaN  8.636004
# 1180945            NaN  8.636004
# 1180945            NaN  8.636004
# 1180945            NaN  8.636004
# 1180945            NaN  8.636004
# 1180945            NaN  8.636004
# 1180945      13.379990  8.636004
# 1180945            NaN  8.636004
# 1180945       6.069992  8.636004
#
# [10 rows x 24 columns]

# %% [markdown]
# ## Distribution des données
#
# On s'intéresse à la distribution des données, en particulier la quantité de données manquantes et la distribution de la quantité à prédire.
#
# La ligne count nous permet d'évaluer que pour la plupart des colonnes, environ la moitié des données sont manquantes.
# La distribution de la colonne Expected est particulière dans le sens où les 3 premiers quartiles sont très bas (respectivement 0.25, 1.02 et 3.81) alors que la moyenne est à 108.63 et le maximum à 33017.73.
# C'est-à-dire que la grande majorité des valeurs sont très petites et les grandes valeurs sont extrêmement grandes.
# Ceci explique aussi le choix d'une pénalisation sur la norme L1 plutot que L2 qui risquerait de donner un poids démesuré à ces valeurs extrêmes.

# %%
dfTrain.describe()
# Out:
#                     Id     minutes_past     radardist_km             Ref  \
# count  13765201.000000  13765201.000000  13765201.000000  6349375.000000
# mean     592336.986614        29.523733        11.067943       22.926658
# std      340856.086254        17.308131         4.206618       10.355157
# min           1.000000         0.000000         0.000000      -31.000000
# 25%      296897.000000        15.000000         9.000000       16.000000
# 50%      592199.000000        30.000000        11.000000       22.500000
# 75%      889582.000000        44.000000        14.000000       29.500000
# max     1180945.000000        59.000000        21.000000       71.000000
#
#          Ref_5x5_10th    Ref_5x5_50th    Ref_5x5_90th    RefComposite  \
# count  5283988.000000  6356482.000000  7551281.000000  6716343.000000
# mean        19.952271       22.610287       25.898461       24.711081
# std          9.208166       10.053000       11.109579       10.689622
# min        -32.000000      -32.000000      -28.500000      -32.000000
# 25%         14.000000       16.000000       18.000000       17.500000
# 50%         20.000000       22.500000       25.500000       24.000000
# 75%         26.000000       29.000000       33.500000       31.500000
# max         62.500000       69.000000       72.500000       92.500000
#
#        RefComposite_5x5_10th  RefComposite_5x5_50th       ...         \
# count         5755673.000000         6711663.000000       ...
# mean               22.158238              24.420753       ...
# std                 9.702705              10.424526       ...
# min               -31.000000             -27.500000       ...
# 25%                16.000000              17.500000       ...
# 50%                22.000000              24.000000       ...
# 75%                28.500000              31.500000       ...
# max                66.000000              71.000000       ...
#
#        RhoHV_5x5_90th             Zdr    Zdr_5x5_10th    Zdr_5x5_50th  \
# count  5905584.000000  4934916.000000  4133154.000000  4936568.000000
# mean         1.015272        0.536709       -0.719008        0.337622
# std          0.048616        1.510399        1.006068        0.938644
# min          0.208333       -7.875000       -7.875000       -7.875000
# 25%          0.998333       -0.187500       -1.125000       -0.062500
# 50%          1.011667        0.375000       -0.625000        0.250000
# 75%          1.051667        1.062500       -0.187500        0.687500
# max          1.051667        7.937500        7.937500        7.937500
#
#          Zdr_5x5_90th             Kdp    Kdp_5x5_10th    Kdp_5x5_50th  \
# count  5905584.000000  4182635.000000  3428782.000000  4187281.000000
# mean         2.072870        0.035452       -3.482325       -0.473655
# std          1.670194        3.869725        2.792120        2.263046
# min         -7.875000      -96.040000      -80.790000      -78.770004
# 25%          1.062500       -1.410004       -4.580002       -0.710007
# 50%          1.687500        0.000000       -2.820007        0.000000
# 75%          2.625000        1.750000       -1.760010        0.349991
# max          7.937500      179.750000        3.519989       12.800003
#
#          Kdp_5x5_90th         Expected
# count  5052776.000000  13765201.000000
# mean         4.079836       108.626306
# std          4.147337       548.605805
# min       -100.200005         0.010000
# 25%          2.069992         0.254000
# 50%          3.519989         1.016000
# 75%          5.639999         3.810002
# max        144.600000     33017.730000
#
# [8 rows x 24 columns]

# %% [markdown]
# Il semble important de souligner le fait que pour chaque séquence de $n$ relevés radars, la production de ces derniers est espacée d'un temps égal. Le premier est produit à 00:00, le dernier à 59:00. De cette manière nous n'avons pas à créer de features trop complexes utilisant cette dimension "minutes_past" et pouvons nous contenter de mesures statistiques comme la moyenne, la std, les quantiles, le min, le max, etc.

# %% [markdown]
# ### Données manquantes
#
# Il y aurait 38% de données manquantes
# https://www.kaggle.com/c/how-much-did-it-rain-ii/forums/t/16572/38-missing-data

# %% [markdown]
# Combien y'a-t-il de données manquantes par dimension ?

# %%
l = float(len(dfTrain["Id"]))
comp = []
for i in dfTrain.columns:
    comp.append([1 - dfTrain[i].isnull().sum() / l , i])
comp.sort(key=lambda x: x[0], reverse=True)
print(comp)
compA = np.array(comp)
# Out:
# [[1.0, 'Id'],
#  [1.0, 'minutes_past'],
#  [1.0, 'radardist_km'],
#  [1.0, 'Expected'],
#  [0.56876779351060691, 'RefComposite_5x5_90th'],
#  [0.54857760522349075, 'Ref_5x5_90th'],
#  [0.48792189812557041, 'RefComposite'],
#  [0.48758191035495957, 'RefComposite_5x5_50th'],
#  [0.46177909062134292, 'Ref_5x5_50th'],
#  [0.4612627886799473, 'Ref'],
#  [0.42902272186217982, 'RhoHV_5x5_90th'],
#  [0.42902272186217982, 'Zdr_5x5_90th'],
#  [0.41813214351174388, 'RefComposite_5x5_10th'],
#  [0.38386566240478437, 'Ref_5x5_10th'],
#  [0.36706881359741861, 'Kdp_5x5_90th'],
#  [0.35862665572409735, 'RhoHV_5x5_50th'],
#  [0.35862665572409735, 'Zdr_5x5_50th'],
#  [0.35850664294695012, 'RhoHV'],
#  [0.35850664294695012, 'Zdr'],
#  [0.30419323335707193, 'Kdp_5x5_50th'],
#  [0.30385571558308522, 'Kdp'],
#  [0.30026107137847102, 'RhoHV_5x5_10th'],
#  [0.30026107137847102, 'Zdr_5x5_10th'],
#  [0.2490905871988357, 'Kdp_5x5_10th']]

# %% [markdown]
# Combien y'a-t-il de séquences totalement nulles sauf minutes_past, radardist_km et expected ?
# > environ 40% du trainset ne possède que des features nulles

# %%
dfLight = dfTrain.drop(['minutes_past','radardist_km', 'Expected'],axis=1)
nbIds = len(dfLight.index)
nbIdsAllNan = len(dfLight.dropna(how='all').index)
nbIdsAnyNan = len(dfLight.dropna(how='any').index)
print "nombre de séquences avec NaN:", nbIds
print "nombre de séquences sans all NaN:", nbIdsAllNan, (nbIdsAllNan * 1. / nbIds * 100)
print "nombre de séquences sans any NaN:", nbIdsAnyNan, (nbIdsAnyNan * 1. / nbIds * 100)
# Out:
# nombre de séquences avec NaN: 13765201
# nombre de séquences sans all NaN: 8476966 61.5825805958
# nombre de séquences sans any NaN: 2769088 20.1165823877

# %% [markdown]
# L'administrateur du challenge précise que les séquences pour lesquelles toutes les Ref (colonne \#4) sont manquantes ne seront pas prises en compte, alors nous allons les enlever.
# https://www.kaggle.com/c/how-much-did-it-rain-ii/forums/t/16622/ignored-ids
#
# Nous travaillons souvent sur un subset pour tester notre code.

# %%
# df = dfTrain[dfTrain.index < 5]

# %%
def myfunc(seq):
    nb = len(seq['Ref'])
    if (seq['Ref'].isnull()).sum() == nb:
        return seq['Id'].values[0]
    return -1
    
def identity(seq):
    print(seq)
    return seq
    
dfGrouped = dfTrain.groupby(dfTrain.index)
dfIds2rmv = dfGrouped.apply(myfunc)

# %%
#dfIds2rmv

# %%
df = dfTrain.drop(dfIds2rmv.values,axis=0)

# %% [markdown]
# Combien a-t-on enlevé de lignes ?

# %%
print len(dfTrain), '*', len(df)*1./len(dfTrain)*100, '% = ', len(df)
# Out:
# 9125329 * 100.0 % =  9125329

# %% [markdown]
# Et maintenant ? Combien y'a-t-il de données manquantes par dimension ?

# %%
l = float(len(df["Id"]))
comp = []
for i in df.columns:
    comp.append([1 - df[i].isnull().sum() / l , i])
comp.sort(key=lambda x: x[0], reverse=True)
comp
# Out:
# [[1.0, 'Id'],
#  [1.0, 'minutes_past'],
#  [1.0, 'radardist_km'],
#  [1.0, 'Expected'],
#  [0.83874674545980754, 'RefComposite_5x5_90th'],
#  [0.81298690710219867, 'Ref_5x5_90th'],
#  [0.73376576340425648, 'RefComposite'],
#  [0.73326320618138807, 'RefComposite_5x5_50th'],
#  [0.6961873922573093, 'Ref_5x5_50th'],
#  [0.69579683099644951, 'Ref'],
#  [0.62983877074459449, 'RefComposite_5x5_10th'],
#  [0.62100906170067949, 'RhoHV_5x5_90th'],
#  [0.62100906170067949, 'Zdr_5x5_90th'],
#  [0.5790412597726613, 'Ref_5x5_10th'],
#  [0.53625069298871308, 'Kdp_5x5_90th'],
#  [0.5287214302081602, 'RhoHV_5x5_50th'],
#  [0.5287214302081602, 'Zdr_5x5_50th'],
#  [0.52724093564188212, 'RhoHV'],
#  [0.52724093564188212, 'Zdr'],
#  [0.44919027029052871, 'Kdp_5x5_50th'],
#  [0.44806943398972243, 'Kdp'],
#  [0.44635716695803518, 'RhoHV_5x5_10th'],
#  [0.44635716695803518, 'Zdr_5x5_10th'],
#  [0.37034357884521207, 'Kdp_5x5_10th']]

# %% [markdown]
# Essayons de trouver des typologies de séquences seulement en les regardants.
# > Ci-dessous on peut voir que certaines colonnes sont totalement vides. Nous pensons alors qu'il va nous falloir développer des algorithmes plus ou moins complexes de remplissage des ces valeurs NaN.

# %%
df.loc[4]
# Out:
#           Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  Ref_5x5_50th  \
# Id_index
# 4          4             0             9  18.5          16.0          19.0
# 4          4             5             9  22.0          14.0          21.0
# 4          4             9             9  35.5          24.5          30.5
# 4          4            14             9  16.5           NaN          19.0
# 4          4            19             9  16.0           NaN          11.0
# 4          4            23             9   NaN           NaN           NaN
# 4          4            28             9  32.5          10.5          34.5
# 4          4            33             9  41.5          33.5          39.5
# 4          4            38             9  34.0          33.5          37.5
# 4          4            42             9  29.5           NaN          29.5
# 4          4            47             9   NaN           NaN           NaN
# 4          4            52             9   NaN           NaN           NaN
# 4          4            56             9  20.0           8.5          16.5
#
#           Ref_5x5_90th  RefComposite  RefComposite_5x5_10th  \
# Id_index
# 4                 23.5          24.5                   22.0
# 4                 30.0          25.5                   22.5
# 4                 35.5          35.5                   25.5
# 4                 34.5          23.5                   16.5
# 4                 18.0          20.5                   13.5
# 4                 26.0           7.5                   12.0
# 4                 43.0          42.5                   19.5
# 4                 44.5          43.0                   36.0
# 4                 42.5          37.0                   35.5
# 4                 45.0          29.5                   19.0
# 4                 20.0          11.0                    NaN
# 4                 11.0           NaN                    NaN
# 4                 20.0          20.0                   10.0
#
#           RefComposite_5x5_50th    ...     RhoHV_5x5_90th    Zdr  \
# Id_index                           ...
# 4                          23.5    ...           0.998333    NaN
# 4                          25.5    ...                NaN    NaN
# 4                          31.5    ...                NaN    NaN
# 4                          23.0    ...                NaN    NaN
# 4                          18.5    ...                NaN    NaN
# 4                          18.5    ...                NaN    NaN
# 4                          39.5    ...                NaN    NaN
# 4                          41.5    ...                NaN    NaN
# 4                          39.0    ...                NaN    NaN
# 4                          29.5    ...                NaN    NaN
# 4                          12.5    ...           1.008333    NaN
# 4                           6.5    ...           1.005000    NaN
# 4                          17.5    ...           1.051667 -1.125
#
#           Zdr_5x5_10th  Zdr_5x5_50th  Zdr_5x5_90th       Kdp  Kdp_5x5_10th  \
# Id_index
# 4                  NaN           NaN        1.4375       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN           NaN       NaN           NaN
# 4                  NaN           NaN        0.5625       NaN           NaN
# 4                  NaN           NaN        0.5625       NaN           NaN
# 4                  NaN           0.5        3.5000  7.029999           NaN
#
#           Kdp_5x5_50th  Kdp_5x5_90th  Expected
# Id_index
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN           NaN  4.064002
# 4                  NaN      5.629990  4.064002
# 4                  NaN           NaN  4.064002
# 4                    0      7.029999  4.064002
#
# [13 rows x 24 columns]

# %% [markdown]
# ### Outliers
# https://www.kaggle.com/sudalairajkumar/how-much-did-it-rain-ii/rainfall-test/log
# Les valeurs de expected au dessus de 1000 mm/h peuvent être des erreurs
#
# ou alors
#
# https://www.kaggle.com/c/how-much-did-it-rain/forums/t/11479/expected/62593
# Some of the extremely high Expected values may be due to the melting of ice precipitation that has collected in the rain gauge, which would release a flood of water in a relatively short period of time. If the rain gauges are heated, then snow filling the gauge and then melting later should not be as much of an issue, but hail or graupel filling the top of the gauge could cause underestimation initially by blocking rain from entering the gauge, then overestimation due to melting and draining into the gauge. The real trick will be to train an algorithm to recognize these instances.

# %%
dfTrainGb = df.groupby(df.index)
exp_rainfall = np.sort(np.array(dfTrainGb['Expected'].aggregate('mean')))
plt.figure()
plt.scatter(np.arange(exp_rainfall.shape[0]), exp_rainfall)
plt.title("Scatterplot for Rainfall distribution in train sample")
plt.ylabel("Rainfall in mm")
plt.show()

# %%
print "nombre d'outliers ? ", exp_rainfall[exp_rainfall >= 1000].shape[0]
print "pourcentage d'outliers ? ", exp_rainfall[exp_rainfall >= 1000].shape[0] * 1. / exp_rainfall.shape[0] * 100
# Out:
# nombre d'outliers ?  4864
# pourcentage d'outliers ?  0.664884164712

# %% [markdown]
# - Doit-on retirer ces valeurs lors de l'apprentissage de notre modèle ?
# > Intuitivement non, car elles sont fortement prises en compte par notre critère MAE
#
# - Correspondent-elles à des erreurs de mesures détectables ?
# > Deux grandes approches possibles pour http://eprints.whiterose.ac.uk/767/1/hodgevj4.pdf. La première consiste à utiliser un algorithme d'apprentissage non supervisé comme K-Means et voir si un ou plusieurs clusters regroupent une grande partie des outliers. La seconde consiste à entraîner un classifeur binaire à détecter les outliers. Intuitivement, cette deuxième approche parraît plus efficace si le classifieur généralise assez, car nous n'avons que 4864 exemples d'outliers. Il faudra aussi choisir 4864 exemples représentatifs des non outliers. On notera que d'après http://ijcttjournal.org/Volume3/issue-2/IJCTT-V3I2P118.pdf, il est possible de détecter des outliers de façon non supervisés avec des algorithmes comme One-class SVMs ou One-class Kernel Fisher Discriminants.

# %% [markdown]
# ### Modèles simples
#
# Nous allons créer des modèles simples (marshall palmer, moyenne Extracted, median Extracted) afin de pouvoir interpréter les résultats de nos futurs modèles.

# %%
size = len(df)
df_train = df[:(size*70/100)]
df_test  = df[(size*70/100):]
print len(df_train), '+', len(df_test), '=', len(df)
# Out:
# 6387730 + 2737599 = 9125329

# %%
# %%time
def myfunc(seq):
    rslt = seq.mean()
    return rslt

f_df_test = df_test['Expected']
f_df_test = f_df_test.groupby(f_df_test.index).apply(myfunc)
f_df_test = f_df_test.to_frame('Expected')
# Out:
# CPU times: user 9.92 s, sys: 0 ns, total: 9.92 s
# Wall time: 9.92 s

# %%
# %%time
f_df_test = df_test['Expected']
f_df_test = f_df_test.groupby(f_df_test.index).mean()
f_df_test = f_df_test.to_frame('Expected')
# Out:
# CPU times: user 44 ms, sys: 0 ns, total: 44 ms
# Wall time: 61.7 ms

# %% [markdown]
# #### Marshall Palmer
#
# https://en.wikipedia.org/wiki/DBZ_(meteorology)

# %%
from sklearn.metrics import mean_absolute_error

def marshall_palmer(ref, minutes_past):
    #print "Estimating rainfall from {0} observations".format(len(minutes_past))
    # how long is each observation valid?
    valid_time = np.zeros_like(minutes_past)
    valid_time[0] = minutes_past.iloc[0]
    for n in xrange(1, len(minutes_past)):
        valid_time[n] = minutes_past.iloc[n] - minutes_past.iloc[n-1]
    valid_time[-1] = valid_time[-1] + 60 - np.sum(valid_time)
    valid_time = valid_time / 60.0

    # sum up rainrate * validtime
    sum = 0
    for dbz, hours in zip(ref, valid_time):
        # See: http s://en.wikipedia.org/wiki/DBZ_(meteorology)
        if np.isfinite(dbz):
            mmperhr = pow(pow(10, dbz/10)/200, 0.625)
            sum = sum + mmperhr * hours
    return sum

# %%
# %%time
# each unique Id is an hour of data at some gauge
def myfunc(seq):
    #rowid = hour['Id'].iloc[0]
    # sort hour by minutes_past
    seq = seq.sort('minutes_past', ascending=True)
    mp = marshall_palmer(seq['Ref'], seq['minutes_past'])
    #print(type(seq.mean()))
    rslt = seq.mean()
    rslt['Marshall_Palmer'] = mp
    return rslt

f_df_mp = df[['minutes_past', 'Ref', 'Expected']]
f_df_mp = f_df_mp.groupby(f_df_mp.index).apply(myfunc)
# Out:
# CPU times: user 20min 11s, sys: 11 s, total: 20min 22s
# Wall time: 20min 24s
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
mean_absolute_error(f_df_mp['Marshall_Palmer'], f_df_mp['Expected'])
# Out:
# 23.43039549242723

# %% [markdown]
# #### Mean

# %%
labels = np.zeros(len(f_df_test['Expected']))
labels.fill(f_df_mp['Expected'].mean())
mean_absolute_error(labels, f_df_test['Expected'])
# Out:
# 41.381186084833658

# %% [markdown]
# #### Median

# %%
labels = np.zeros(len(f_df_test['Expected']))
labels.fill(f_df_mp['Expected'].median())
mean_absolute_error(labels, f_df_test['Expected'])
# Out:
# 23.912179743020168

# %% [markdown]
# ### Modèles bourins

# %% [markdown]
# #### Few features

# %% [markdown]
# https://www.kaggle.com/c/how-much-did-it-rain/forums/t/14242/congratulations
#
# Extractions de features
# - Marshall Palmer
# - interpolation avant aggrégation sur la séquence
# - complétion des valeurs NaN : mean(, median, 0)

# %%
size = len(df)
pc = .0010 # 0.5% -> 2h pour tout process
dfTry = df[:int(size * pc)]
len(dfTry)
# Out:
# 9125

# %%
f_cols = ['radardist_km', 'Ref', 'Ref_5x5_10th', 'Ref_5x5_50th',
       'Ref_5x5_90th', 'RefComposite', 'RefComposite_5x5_10th',
       'RefComposite_5x5_50th', 'RefComposite_5x5_90th', 'RhoHV',
       'RhoHV_5x5_10th', 'RhoHV_5x5_50th', 'RhoHV_5x5_90th', 'Zdr',
       'Zdr_5x5_10th', 'Zdr_5x5_50th', 'Zdr_5x5_90th', 'Kdp',
       'Kdp_5x5_10th', 'Kdp_5x5_50th', 'Kdp_5x5_90th', 'Marshall_Palmer']

# %%
f_interpolable = ['Ref', 'Ref_5x5_10th', 'Ref_5x5_50th',
       'Ref_5x5_90th', 'RefComposite', 'RefComposite_5x5_10th',
       'RefComposite_5x5_50th', 'RefComposite_5x5_90th', 'RhoHV',
       'RhoHV_5x5_10th', 'RhoHV_5x5_50th', 'RhoHV_5x5_90th', 'Zdr',
       'Zdr_5x5_10th', 'Zdr_5x5_50th', 'Zdr_5x5_90th', 'Kdp',
       'Kdp_5x5_10th', 'Kdp_5x5_50th', 'Kdp_5x5_90th']

# %%
# %%time
def myfunc(seq):
    seq = seq.sort('minutes_past', ascending=True)
    mp = marshall_palmer(seq['Ref'], seq['minutes_past'])
    for f_name in f_interpolable: 
        seq[f_name] = seq[f_name].interpolate()
    rslt = seq.mean()
    rslt['Marshall_Palmer'] = mp
    return rslt

f_df = dfTry
f_df = f_df.groupby(f_df.index).apply(myfunc)
# Out:
# CPU times: user 11min 42s, sys: 2.76 s, total: 11min 45s
# Wall time: 11min 46s
# /Library/Python/2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app

# %% [markdown]
# Combien y'a-t-il encore de valeurs NaN pour chaque dimension ?

# %%
f_df.describe()
# Out:
#        radardist_km          Ref  Ref_5x5_10th  Ref_5x5_50th  Ref_5x5_90th  \
# count   3835.000000  3835.000000   3835.000000   3835.000000   3835.000000
# mean       9.926467    20.553738     18.005898     20.271493     24.009619
# std        4.244216     8.918461      7.594057      8.838795      9.627939
# min        0.000000   -26.900000    -29.900000    -28.583333    -23.750000
# 25%        7.000000    15.500000     14.361111     15.228220     18.041667
# 50%       11.000000    20.928571     18.005898     20.357143     24.431818
# 75%       13.000000    26.419872     22.333333     26.098077     30.810096
# max       20.000000    46.357143     40.250000     44.142857     57.100000
#
#        RefComposite  RefComposite_5x5_10th  RefComposite_5x5_50th  \
# count   3835.000000            3835.000000            3835.000000
# mean      22.360804              20.062580              22.077436
# std        9.312599               8.231645               9.250305
# min      -22.333333             -24.583333             -21.583333
# 25%       16.666667              15.805556              16.166667
# 50%       22.687500              20.062580              22.227273
# 75%       28.775253              25.000000              28.432692
# max       50.857143              41.538462              48.000000
#
#        RefComposite_5x5_90th        RhoHV       ...         RhoHV_5x5_90th  \
# count            3835.000000  3835.000000       ...            3835.000000
# mean               25.777455     0.979369       ...               1.014720
# std                 9.887774     0.056073       ...               0.040121
# min               -14.250000     0.288667       ...               0.208333
# 25%                19.464286     0.977278       ...               1.002735
# 50%                26.318182     0.980641       ...               1.014720
# 75%                33.100000     0.999833       ...               1.035606
# max                57.583333     1.051667       ...               1.051667
#
#                Zdr  Zdr_5x5_10th  Zdr_5x5_50th  Zdr_5x5_90th          Kdp  \
# count  3835.000000   3835.000000   3835.000000   3835.000000  3835.000000
# mean      0.619037     -0.671884      0.304566      1.944788    -0.042633
# std       0.886333      0.694623      0.696922      1.094536     2.169628
# min      -7.875000     -7.875000     -7.875000     -6.750000   -25.130005
# 25%       0.245164     -0.875000      0.081818      1.406250    -0.391339
# 50%       0.619037     -0.671884      0.304566      1.944788    -0.042633
# 75%       0.797476     -0.422476      0.517637      2.194231     0.375967
.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# Avant de finaliser notre modèle, nous devons trouver un moyen de remplir les valeurs nulles, nous choisissons la moyenne sur tous les exemples.

# %%
y = f_df.Expected
f_df = f_df[f_cols].apply(lambda x: x.fillna(x.mean()), axis=0)

# %%
size = len(f_df)
pc = .80
X_train = f_df[:int(size* pc)]
y_train = y[:int(size* pc)]
X_test  = f_df[int(size* pc):]
y_test  = y[int(size* pc):]
print len(X_train), '+', len(X_test), '=', len(f_df)
# Out:
# 59469 + 14868 = 74337

# %% [markdown]
# ##### Machines d'apprentissage linéaires

# %%
# %%time
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test)) # linear regression 41.82
# Out:
# 40.9886404235
# CPU times: user 79.6 ms, sys: 16.2 ms, total: 95.8 ms
# Wall time: 79.3 ms

# %%
# %%time
from sklearn.linear_model import Ridge
model = Ridge()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test))
# Out:
# 40.9821487381
# CPU times: user 23.9 ms, sys: 29.4 ms, total: 53.3 ms
# Wall time: 58.2 ms

# %%
# %%time
from sklearn import svm
model = svm.SVR(kernel='linear')
model.fit(X_train, y_train) # 40 min pour 100% du trainset
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test))
# Out:
# 21.4826468085
# CPU times: user 2h 12min 20s, sys: 24.2 s, total: 2h 12min 44s
# Wall time: 2h 12min 56s

# %% [markdown]
# ##### Machines d'apprentissage non-linéaires (ou noyau rbf)

# %%
# %%time
from sklearn import svm
model = svm.SVR(kernel='rbf')
model.fit(X_train, y_train) # 2h pour 100% du trainset
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test)) # SVR 21.55
# Out:
# 21.5541279418
# CPU times: user 16min 44s, sys: 2.67 s, total: 16min 47s
# Wall time: 16min 47s

# %% [markdown]
# ##### Ensembles de machines d'apprentissages

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=50)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test))
# Out:
# 36.6529892279
# CPU times: user 1min 33s, sys: 790 ms, total: 1min 34s
# Wall time: 1min 35s

# %%
# %%time
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor(n_estimators=800)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test))
# Out:
# 34.1299716137
# CPU times: user 4min 53s, sys: 8.31 s, total: 5min 1s
# Wall time: 5min 2s

# %%
# %%time
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test))
# Out:
# 37.8291353907
# CPU times: user 18.8 s, sys: 279 ms, total: 19.1 s
# Wall time: 19.1 s

# %% [markdown]
# #### Full Features

# %% [markdown]
# https://www.kaggle.com/c/how-much-did-it-rain/forums/t/14242/congratulations
#
# Extractions de features
# - Marshall Palmer
# - interpolation
# - dans la séquence
#   - longueur
#   - si toutes les valeurs sont NaN
#   - pourcentage de valeurs NaN
#   - moyenne
#   - std
#   - min
#   - max
#   - quantiles
# - complétion des valeurs NaN : median(, mean, 0)

# %%
size = len(df)
pc = .0010 # 0.5% -> 2h pour tout process
dfTry = df[:int(size * pc)]
len(dfTry)
# Out:
# 9125

# %%
f_cols = ['radardist_km', 'Ref', 'Ref_5x5_10th', 'Ref_5x5_50th',
       'Ref_5x5_90th', 'RefComposite', 'RefComposite_5x5_10th',
       'RefComposite_5x5_50th', 'RefComposite_5x5_90th', 'RhoHV',
       'RhoHV_5x5_10th', 'RhoHV_5x5_50th', 'RhoHV_5x5_90th', 'Zdr',
       'Zdr_5x5_10th', 'Zdr_5x5_50th', 'Zdr_5x5_90th', 'Kdp',
       'Kdp_5x5_10th', 'Kdp_5x5_50th', 'Kdp_5x5_90th', 'Marshall_Palmer']

# %%
f_interpolable = ['Ref', 'Ref_5x5_10th', 'Ref_5x5_50th',
       'Ref_5x5_90th', 'RefComposite', 'RefComposite_5x5_10th',
       'RefComposite_5x5_50th', 'RefComposite_5x5_90th', 'RhoHV',
       'RhoHV_5x5_10th', 'RhoHV_5x5_50th', 'RhoHV_5x5_90th', 'Zdr',
       'Zdr_5x5_10th', 'Zdr_5x5_50th', 'Zdr_5x5_90th', 'Kdp',
       'Kdp_5x5_10th', 'Kdp_5x5_50th', 'Kdp_5x5_90th']

# %% [markdown]
# ######Sans interpolation

# %%
# %%time
def myfunc(seq):
    seq = seq.sort_values('minutes_past', ascending=True)
    mp = marshall_palmer(seq['Ref'], seq['minutes_past'])
    return mp
    
# création de colonnes booléennes : True si NaN
for f_name in f_interpolable:
    dfTry[f_name + '_isnull'] = dfTry[f_name].isnull()
    
df_g = dfTry.groupby(dfTry.index)

f_df = pd.DataFrame(index=dfTry.index.unique())

f_df['length'] = df_g.size()
f_df['radardist_km'] = df_g['radardist_km'].mean() # tous les éléments d'une séquence sont égaux

for f_name in f_interpolable:
    f_df[f_name + '_nbNaN'] = df_g[f_name + '_isnull'].sum()
    f_df[f_name + '_isNaN'] = f_df[f_name + '_nbNaN'] == f_df['length']
    f_df[f_name + '_pcNaN'] = f_df[f_name + '_nbNaN'] * 1. / f_df['length']
    f_df.drop(f_name + '_nbNaN', axis=1) # optionnel
    
f_df['Marshall_Palmer'] = df_g[['Ref','minutes_past']].apply(myfunc)
for f_name in f_interpolable:
    f_df[f_name + '_mean'] = df_g[f_name].mean()
    f_df[f_name + '_std'] = df_g[f_name].std()
    f_df[f_name + '_min'] = df_g[f_name].min()
    f_df[f_name + '_max'] = df_g[f_name].max()
    for pc in [.1,.3,.5,.7,.9]:
        f_df[f_name + '_qtil_' + str(pc)] = df_g[f_name].quantile(pc)
# Out:
# CPU times: user 23.3 s, sys: 262 ms, total: 23.6 s
# Wall time: 24.7 s
# /Library/Python/2.7/site-packages/IPython/kernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
f_df.describe()
# Out:
#            length  radardist_km   Ref_nbNaN Ref_isNaN   Ref_pcNaN  \
# count  770.000000    770.000000  770.000000       770  770.000000
# mean    11.850649      9.872727    3.638961         0    0.305202
# std      2.934443      4.235206    4.105506         0    0.316624
# min      6.000000      0.000000    0.000000     False    0.000000
# 25%     11.000000      7.000000    0.000000         0    0.000000
# 50%     12.000000     11.000000    2.000000         0    0.200000
# 75%     13.000000     13.000000    6.000000         0    0.583333
# max     19.000000     20.000000   18.000000     False    0.947368
#
#        Ref_5x5_10th_nbNaN Ref_5x5_10th_isNaN  Ref_5x5_10th_pcNaN  \
# count          770.000000                770          770.000000
# mean             4.933766           0.137662            0.415634
# std              4.875514           0.344769            0.379850
# min              0.000000              False            0.000000
# 25%              0.000000                  0            0.000000
# 50%              4.000000                  0            0.384615
# 75%              8.000000                  0            0.769231
# max             18.000000               True            1.000000
#
#        Ref_5x5_50th_nbNaN Ref_5x5_50th_isNaN          ...            \
# count          770.000000                770          ...
# mean             3.625974          0.0272727          ...
# std              4.257065           0.162983          ...
# min              0.000000              False          ...
# 25%              0.000000                  0          ...
# 50%              2.000000                  0          ...
# 75%              6.000000                  0          ...
# max             18.000000               True          ...
#
#        Kdp_5x5_50th_qtil_0.9  Kdp_5x5_90th_mean Kdp_5x5_90th_std  \
# count             524.000000         562.000000       540.000000
# mean                0.511655           3.514550         2.792860
# std                 1.396023           2.574053         2.252363
# min               -19.680008         -10.860001         0.000000
# 25%                 0.314992           2.078246         1.398291
# 50%                 0.672492           3.449541         2.235472
# 75%                 1.059998           4.980995         3.423191
# max                 4.190002          19.269989        19.205023
#
#        Kdp_5x5_90th_min  Kdp_5x5_90th_max Kdp_5x5_90th_qtil_0.1  \
# count        562.000000        562.000000            562.000000
# mean          -0.023902          7.958217              1.118004
# std            4.502706          5.354113              3.095978
# min          -35.180008        -10.860001            -21.038004
# 25%           -0.250008          4.580002              0.709991
# 50%            1.050003          7.065003              1.551493
# 75%            1.759994         10.519989              2.295744
# max           19.269989         43.209990             19.269989
#
#        Kdp_5x5_90th_qtil_0.3  Kdp_5x5_90th_qtil_0.5 Kdp_5x5_90th_qtil_0.7  \
# count             562.000000             562.000000            562.000000
# mean                2.364444               3.317059              4.384880
# std                 2.482304               2.427089              2.640555
# min               -15.892007             -11.240005            -10.860001
# 25%                 1.417244               2.114998              2.653247
# 50%                 2.447494               3.169998              4.226994
# 75%                 3.462749               4.564995              5.979996
# max                19.269989              19.269989             19.269989
#
#        Kdp_5x5_90th_qtil_0.9
# count             562.000000
# mean                6.094042
# std                 3.470166
# min               -10.860001
# 25%                 3.690746
# 50%                 5.879990
# 75%                 8.008245
# max                22.067992
#
# [8 rows x 243 columns]

# %% [markdown]
# ###### avec interpolation

# %%
# %%time
def myfunc(seq):
    seq = seq.sort_values('minutes_past', ascending=True)
    mp = marshall_palmer(seq['Ref'].interpolate(), seq['minutes_past']) # interpolate
    return mp

def interpolate(seq):
    seq = seq.interpolate()
    return seq
    
# création de colonnes booléennes : True si NaN
for f_name in f_interpolable:
    dfTry[f_name + '_isnull'] = dfTry[f_name].isnull()
    
df_g = dfTry.groupby(dfTry.index)

f_df = pd.DataFrame(index=dfTry.index.unique())

f_df['length'] = df_g.size()
f_df['radardist_km'] = df_g['radardist_km'].mean() # tous les éléments d'une séquence sont égaux

for f_name in f_interpolable:
    f_df[f_name + '_nbNaN'] = df_g[f_name + '_isnull'].sum()
    f_df[f_name + '_isNaN'] = f_df[f_name + '_nbNaN'] == f_df['length']
    f_df[f_name + '_pcNaN'] = f_df[f_name + '_nbNaN'] * 1. / f_df['length']
    f_df.drop(f_name + '_nbNaN', axis=1) # optionnel

# rajoute 15% de temps de calcule    
tmp = df_g[f_interpolable].apply(interpolate).groupby(dfTry.index) 
for f_name in f_interpolable: 
    f_df[f_name + '_mean'] = tmp[f_name].mean()
    f_df[f_name + '_std'] = tmp[f_name].std()
    f_df[f_name + '_min'] = tmp[f_name].min()
    f_df[f_name + '_max'] = tmp[f_name].max()
    for pc in [.1,.3,.5,.7,.9]:
        f_df[f_name + '_qtil_' + str(pc)] = tmp[f_name].quantile(pc)
    
f_df['Marshall_Palmer'] = df_g[['Ref','minutes_past']].apply(myfunc)
# Out:
# CPU times: user 25.6 s, sys: 274 ms, total: 25.8 s
# Wall time: 27.4 s
# /Library/Python/2.7/site-packages/IPython/kernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
f_df.describe()
# Out:
#            length  radardist_km   Ref_nbNaN Ref_isNaN   Ref_pcNaN  \
# count  770.000000    770.000000  770.000000       770  770.000000
# mean    11.850649      9.872727    3.638961         0    0.305202
# std      2.934443      4.235206    4.105506         0    0.316624
# min      6.000000      0.000000    0.000000     False    0.000000
# 25%     11.000000      7.000000    0.000000         0    0.000000
# 50%     12.000000     11.000000    2.000000         0    0.200000
# 75%     13.000000     13.000000    6.000000         0    0.583333
# max     19.000000     20.000000   18.000000     False    0.947368
#
#        Ref_5x5_10th_nbNaN Ref_5x5_10th_isNaN  Ref_5x5_10th_pcNaN  \
# count          770.000000                770          770.000000
# mean             4.933766           0.137662            0.415634
# std              4.875514           0.344769            0.379850
# min              0.000000              False            0.000000
# 25%              0.000000                  0            0.000000
# 50%              4.000000                  0            0.384615
# 75%              8.000000                  0            0.769231
# max             18.000000               True            1.000000
#
#        Ref_5x5_50th_nbNaN Ref_5x5_50th_isNaN       ...         \
# count          770.000000                770       ...
# mean             3.625974          0.0272727       ...
# std              4.257065           0.162983       ...
# min              0.000000              False       ...
# 25%              0.000000                  0       ...
# 50%              2.000000                  0       ...
# 75%              6.000000                  0       ...
# max             18.000000               True       ...
#
#        Kdp_5x5_90th_mean  Kdp_5x5_90th_std Kdp_5x5_90th_min  Kdp_5x5_90th_max  \
# count         562.000000        558.000000       562.000000        562.000000
# mean            3.438748          2.527287        -0.023902          7.958217
# std             2.934268          1.957799         4.502706          5.354113
# min           -14.763343          0.000000       -35.180008        -10.860001
# 25%             1.871554          1.240787        -0.250008          4.580002
# 50%             3.391565          2.131065         1.050003          7.065003
# 75%             4.941337          3.280490         1.759994         10.519989
# max            19.269989         13.414649        19.269989         43.209990
#
#        Kdp_5x5_90th_qtil_0.1 Kdp_5x5_90th_qtil_0.3  Kdp_5x5_90th_qtil_0.5  \
# count             562.000000            562.000000             562.000000
# mean                1.040617              2.247708               3.249228
# std                 3.367632              3.179840               3.168657
# min               -22.756806            -20.220001             -20.220001
# 25%                 0.680493              1.302742               1.904993
# 50%                 1.621491              2.414993               3.154991
# 75%                 2.462996              3.504498               4.564995
# max                19.269989             22.610000              22.610000
#
#        Kdp_5x5_90th_qtil_0.7 Kdp_5x5_90th_qtil_0.9  Marshall_Palmer
# count             562.000000            562.000000       770.000000
# mean                4.327117              5.996803         2.074880
# std                 3.178352              3.691853         3.424679
# min               -17.980011            -10.860001         0.005011
# 25%                 2.556898              3.594996         0.370276
# 50%                 4.145998              5.804994         0.914488
# 75%                 5.936248              7.904498         2.382719
# max                22.610000             22.610000        47.078442
#
# [8 rows x 243 columns]

# %%
y = f_df.Expected
f_df = f_df[f_cols].apply(lambda x: x.fillna(x.median()), axis=0)

# %%
size = len(f_df)
pc = .80
X_train = f_df[:int(size* pc)]
y_train = y[:int(size* pc)]
X_test  = f_df[int(size* pc):]
y_test  = y[int(size* pc):]
print len(X_train), '+', len(X_test), '=', len(f_df)

# %%
# %%time
from sklearn.linear_model import Ridge
model = Ridge()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test))

# %%
# %%time
from sklearn import svm
model = svm.SVR(kernel='rbf')
model.fit(X_train, y_train) # 2h pour 100% du trainset
y_pred = model.predict(X_test)
print(mean_absolute_error(y_pred, y_test)) # SVR 21.55

# %%
import sys
import time
import numpy as np
import pandas as pd

from sklearn.svm import SVR

sys.argv = ['Test', '1', '1']

featuresSet="basic"
#featuresSet="interpolate"

t_start = time.time()

model = SVR(C=float(sys.argv[1]))

l_dfTrain = []
l_dfTest = []
trainSets = sys.argv[2:]

print "Model: SVR(C=", sys.argv[1] +")"
print "Training Sets: ", trainSets

for i in xrange(1,16+1):
    if str(i) in trainSets:
        print "Loading dataset basic_" + str(i) + 'sur16 into trainSets...'        
        l_dfTrain.append(pd.read_csv('./data/f_df_train_' + featuresSet + '_'+str(i)+'sur16.csv', index_col=0))
    else:
        print "Loading dataset basic_" + str(i) + 'sur16 into testSets...'        
        l_dfTest.append(pd.read_csv('./data/f_df_train_' + featuresSet + '_'+str(i)+'sur16.csv', index_col=0))

dfTrain = pd.concat(l_dfTrain)
dfTest = pd.concat(l_dfTest)

yTrain = dfTrain.Expected
yTest = dfTest.Expected

dfTrain.drop('Expected',axis=1,inplace=True)
dfTest.drop('Expected',axis=1,inplace=True)

print "Training SVR with rbf Kernel..."
model.fit(dfTrain, yTrain)

print "Predicting values..."
pred = model.predict(dfTest)

print "Calculating MAE scores:"
scores = (np.abs(pred - yTest)).mean()
print scores
print ""

t_end = time.time()
print "Time to process: ", t_end - t_start
# Out:
# Model: SVR(C= 1)
# Training Sets:  ['1']
# Loading dataset basic_1sur16 into trainSets...
# Loading dataset basic_2sur16 into testSets...
# Loading dataset basic_3sur16 into testSets...
# Loading dataset basic_4sur16 into testSets...
# Loading dataset basic_5sur16 into testSets...
# Loading dataset basic_6sur16 into testSets...
# Loading dataset basic_7sur16 into testSets...
# Loading dataset basic_8sur16 into testSets...
# Loading dataset basic_9sur16 into testSets...
# Loading dataset basic_10sur16 into testSets...
# Loading dataset basic_11sur16 into testSets...
# Loading dataset basic_12sur16 into testSets...
# Loading dataset basic_13sur16 into testSets...
# Loading dataset basic_14sur16 into testSets...
# Loading dataset basic_15sur16 into testSets...
# Loading dataset basic_16sur16 into testSets...
# Training SVR with rbf Kernel...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-44a70cb98582> in <module>()
#      40
#      41 print "Training SVR with rbf Kernel..."
# ---> 42 model.fit(dfTrain, yTrain)
#      43
#      44 print "Predicting values..."
#
# /users/Etu1/3152691/.local/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y, sample_weight)
#     148         self._sparse = sparse and not callable(self.kernel)
#     149
# --> 150         X = check_array(X, accept_sparse='csr', dtype=np.float64, order='C')
#     151         y = self._validate_targets(y)
#     152
#
# /users/Etu1/3152691/.local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     396                              % (array.ndim, estimator_name))
#     397         if force_all_finite:
# --> 398             _assert_all_finite(array)
#     399
#     400     shape_repr = _shape_repr(array.shape)
#
# /users/Etu1/3152691/.local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _assert_all_finite(X)
#      52             and not np.isfinite(X).all()):
#      53         raise ValueError("Input contains NaN, infinity"
# ---> 54                          " or a value too large for %r." % X.dtype)
#      55
#      56
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
i=2
dfTrain = pd.read_csv("data/f_df_train_interpolate_"+str(i)+"sur16.csv")
yTrain = pd.read_csv("data/f_df_train_basic_"+str(i)+"sur16.csv")
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-5-dc3771a3f722> in <module>()
#       1 i=2
# ----> 2 dfTrain = pd.read_csv("data/f_df_train_interpolate_"+str(i)+"sur16.csv")
#       3 yTrain = pd.read_csv("data/f_df_train_basic_"+str(i)+"sur16.csv")
#
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     232
#     233     # Create the parser.
# --> 234     parser = TextFileReader(filepath_or_buffer, **kwds)
#     235
#     236     if (nrows is not None) and (chunksize is not None):
#
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     540             self.options['has_index_names'] = kwds['has_index_names']
#     541
# --> 542         self._make_engine(self.engine)
#     543
#     544     def _get_options_with_defaults(self, engine):
#
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     677     def _make_engine(self, engine='c'):
#     678         if engine == 'c':
# --> 679             self._engine = CParserWrapper(self.f, **self.options)
#     680         else:
#     681             if engine == 'python':
#
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1039         kwds['allow_leading_cols'] = self.index_col is not False
#    1040
# -> 1041         self._reader = _parser.TextReader(src, **kwds)
#    1042
#    1043         # XXX
#
# parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3218)()
#
# parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5594)()
#
# IOError: File data/f_df_train_interpolate_2sur16.csv does not exist

# %%
yTrain
# Out:
#        length  radardist_km      Id  Ref_nbNaN Ref_isNaN  Ref_pcNaN  \
# 0          15            14   77148          0     False   0.000000
# 1          11            15   77149          6     False   0.545455
# 2          13            14   77151          0     False   0.000000
# 3          12            11   77154          1     False   0.083333
# 4          16            14   77155          1     False   0.062500
# 5          15            12   77156          3     False   0.200000
# 6          12            17   77159          3     False   0.250000
# 7          10            11   77161          0     False   0.000000
# 8          12             3   77163          0     False   0.000000
# 9          11             7   77164          6     False   0.545455
# 10         11             9   77166          0     False   0.000000
# 11         13            11   77168          5     False   0.384615
# 12         12             6   77169          0     False   0.000000
# 13         11            14   77171          0     False   0.000000
# 14         13            10   77172          0     False   0.000000
# 15         16            12   77173          0     False   0.000000
# 16         13            14   77174         12     False   0.923077
# 17         14            11   77176          2     False   0.142857
# 18         13            12   77177          0     False   0.000000
# 19          9            15   77178          7     False   0.777778
# 20         12             7   77179          0     False   0.000000
# 21         12            16   77182          8     False   0.666667
# 22         16            14   77183          5     False   0.312500
# 23         13             1   77184          0     False   0.000000
# 24         13             6   77185          0     False   0.000000
# 25         16            13   77186          0     False   0.000000
# 26          6             5   77187          5     False   0.833333
# 27         10            16   77189          7     False   0.700000
# 28         19            15   77191          7     False   0.368421
# 29         12             9   77192          0     False   0.000000
# ...       ...           ...     ...        ...       ...        ...
# 45693      14            11  147796          0     False   0.000000
# 45694      18            11  147798          1     False   0.055556
# 45695      11            11  147799          0     False   0.000000
# 45696      11            11  147801          0     False   0.000000
# 45697      12            10  147804          0     False   0.000000
# 45698      13            13  147805          4     False   0.307692
# 45699      12            12  147807          4     False   0.333333
# 45700      11             5  147808          4     False   0.363636
# 45701      15             6  147809          7     False   0.466667
# 45702      18            12  147815          3     False   0.166667
# 45703      14             9  147816          3     False   0.214286
# 45704      18            11  147817          6     False   0.333333
# 45705      13            11  147818          0     False   0.000000
# 45706       6             5  147820          1     False   0.166667
# 45707      10            10  147822          8     False   0.800000
# 45708      10            14  147823          0     False   0.000000
# 45709      18             7  147824         17     False   0.944444
# 45710      10             4  147826          0     False   0.000000
# 45711      14             7  147827          0     False   0.000000
# 45712      13             4  147828          0     False   0.000000
# 45713      15            11  147829         12     False   0.800000
# 45714      12             3  147831          0     False   0.000000
# 45715      13             5  147832          0     False   0.000000
# 45716      12            12  147833          0     False   0.000000
# 45717      14            11  147834          0     False   0.000000
# 45718      17            14  147836          0     False   0.000000
# 45719      15             7  147838          0     False   0.000000
# 45720      11             5  147839          1     False   0.090909
# 45721      11            10  147842          0     False   0.000000
# 45722      18             8  147844          0     False   0.000000
#
#        Ref_5x5_10th_nbNaN Ref_5x5_10th_isNaN  Ref_5x5_10th_pcNaN  \
# 0                       0              False            0.000000
# 1                       6              False            0.545455
# 2                       0              False            0.000000
# 3                       0              False            0.000000
# 4                       6              False            0.375000
# 5                       3              False            0.200000
# 6                       6              False            0.500000
# 7                       0              False            0.000000
# 8                       0              False            0.000000
# 9                       9              False            0.818182
# 10                      0              False            0.000000
# 11                     13               True            1.000000
# 12                      0              False            0.000000
# 13                      5              False            0.454545
# 14                      0              False            0.000000
# 15                      1              False            0.062500
# 16                     13               True            1.000000
# 17                      5              False            0.357143
# 18                      0              False            0.000000
# 19                      9               True            1.000000
# 20                      0              False            0.000000
# 21                     12               True            1.000000
# 22                      8              False            0.500000
# 23                      0              False            0.000000
# 24                      0              False            0.000000
# 25                      0              False            0.000000
# 26                      6               True            1.000000
# 27                     10               True            1.000000
# 28                     16              False            0.842105
# 29                      0              False            0.000000
# ...                   ...                ...                 ...
# 45693                   0              False            0.000000
# 45694                   4              False            0.222222
# 45695                   0              False            0.000000
# 45696                   0              False            0.000000
# 45697                   0              False            0.000000
# 45698                   8              False            0.615385
# 45699                   6              False            0.500000
# 45700                   4              False            0.363636
# 45701                   9              False            0.600000
# 45702                   9              False            0.500000
# 45703                   7              False            0.500000
# 45704                  11              False            0.611111
# 45705                   0              False            0.000000
# 45706                   2              False            0.333333
# 45707                  10               True            1.000000
# 45708                   0              False            0.000000
# 45709                  18               True            1.000000
# 45710                   0              False            0.000000
# 45711                   0              False            0.000000
# 45712                   0              False            0.000000
# 45713                  13              False            0.866667
# 45714                   2              False            0.166667
# 45715                   0              False            0.000000
# 45716                   0              False            0.000000
# 45717                   0              False            0.000000
# 45718                   0              False            0.000000
# 45719                   0              False            0.000000
# 45720                   1              False            0.090909
# 45721                   8              False            0.727273
# 45722                   0              False            0.000000
#
#        Ref_5x5_50th_nbNaN         ...         Kdp_5x5_90th_mean  \
# 0                       0         ...                  3.898662
# 1                       6         ...                       NaN
# 2                       0         ...                  3.082302
# 3                       0         ...                  3.366661
# 4                       0         ...                 17.143994
# 5                       2         ...                 12.847496
# 6                       2         ...                       NaN
# 7                       0         ...                  4.498993
# 8                       0         ...                  1.584994
# 9                       6         ...                  2.464996
# 10                      0         ...                  5.092722
# 11                      7         ...                 12.827687
# 12                      0         ...                  2.892724
# 13                      0         ...                  3.724540
# 14                      0         ...                  5.699996
# 15                      0         ...                  6.566664
# 16                     12         ...                       NaN
# 17                      1         ...                  9.477994
# 18                      0         ...                  3.969993
# 19                      7         ...                       NaN
# 20                      0         ...                  3.606661
# 21                     10         ...                       NaN
# 22                      5         ...                  5.359995
# 23                      0         ...                  9.064995
# 24                      0         ...                  2.325995
# 25                      0         ...                  4.279371
# 26                      6         ...                       NaN
# 27                      7         ...                       NaN
# 28                      6         ...                  1.055000
# 29                      0         ...                  7.427137
# ...                   ...         ...                       ...
# 45693                   0         ...                  3.744994
# 45694                   1         ...                  9.479996
# 45695                   0         ...                  3.159995
# 45696                   0         ...                  3.993630
# 45697                   0         ...                  7.194992
# 45698                   4         ...                  1.181664
# 45699                   4         ...                  2.922495
# 45700                   4         ...                  1.862850
# 45701                   8         ...                  1.353995
# 45702                   2         ...                  4.045998
# 45703                   3         ...                  3.607855
# 45704                   7         ...                       NaN
# 45705                   0         ...                  6.606917
# 45706                   1         ...                  1.763331
# 45707                   8         ...                  4.234995
# 45708                   0         ...                  5.172995
# 45709                  18         ...                       NaN
# 45710                   0         ...                  2.140993
# 45711                   0         ...                  5.279228
# 45712                   0         ...                  2.543841
# 45713                  11         ...                  5.174993
# 45714                   0         ...                  3.639994
# 45715                   0         ...                  7.267688
# 45716                   0         ...                  3.346663
# 45717                   0         ...                  3.744994
# 45718                   0         ...                       NaN
# 45719                   0         ...                  7.527137
# 45720                   0         ...                  2.692493
# 45721                   0         ...                       NaN
# 45722                   0         ...                  5.757056
#
#        Kdp_5x5_90th_std  Kdp_5x5_90th_min Kdp_5x5_90th_max  \
# 0              1.694993          1.409988         7.399994
# 1                   NaN               NaN              NaN
# 2              1.018693          1.409988         4.889999
# 3              1.310541          1.059998         4.919998
# 4             12.979035          5.979996        33.759995
# 5             13.001117          2.119995        28.949997
# 6                   NaN               NaN              NaN
# 7              1.661074          1.389999         7.279999
# 8              0.412654          1.059998         2.470001
# 9              2.991070          0.349991         4.580002
# 10             2.247726          1.409988         8.440002
# 11             6.807975          4.509995        27.369995
# 12             1.465709          0.709991         4.929993
# 13             1.698402          1.750000         7.229996
# 14             2.749163          2.809998        12.309998
# 15             3.973526          2.470001        15.669998
# 16                  NaN               NaN              NaN
# 17             9.259080          1.759994        22.709991
# 18             2.884514          0.709991        11.399994
# 19                  NaN               NaN              NaN
# 20             1.928436          1.409988         8.449997
# 21                  NaN               NaN              NaN
# 22             5.676861         -1.410004        21.000000
# 23             6.283083          0.000000        14.479996
# 24             1.410936          0.349991         4.929993
# 25             2.283066          1.409988         8.779999
# 26                  NaN               NaN              NaN
# 27                  NaN               NaN              NaN
# 28             4.985105         -2.470001         4.580002
# 29             2.779355          2.819992        11.209991
# ...                 ...               ...              ...
# 45693          1.959349          1.409988         9.139999
# 45694               NaN          9.479996         9.479996
# 45695          1.061161          1.409988         4.580002
# 45696          1.900127          2.059998         8.429993
# 45697          3.747628          3.409988        10.519989
# 45698          6.280489        -11.139999         6.649994
# 45699          4.446974          0.349991        16.750000
# 45700          0.391610          1.409988         2.459992
# 45701         10.919307        -18.160004         6.699997
# 45702          4.454193         -3.089996        11.000000
# 45703          2.992113         -0.699997         8.580002
# 45704               NaN               NaN              NaN
# 45705          1.941847          3.169998        10.009994
# 45706          0.705008          1.059998         2.470001
# 45707          2.875882          1.379990         8.739990
# 45708          2.584454          0.679993         9.080002
# 45709               NaN               NaN              NaN
# 45710          1.000926          0.709991         3.519989
# 45711          3.402419         -1.389999        10.119995
# 45712          1.047128          1.059998         4.529999
# 45713          2.613377          1.759994         9.659988
# 45714          0.784605          2.739990         4.179993
# 45715          2.258082          4.860001        11.779999
# 45716          1.725822          0.360001         6.169998
# 45717          1.959349          1.409988         9.139999
# 45718               NaN               NaN              NaN
# 45719          3.688522          2.470001        12.709991
# 45720          1.733078          1.399994         6.769989
# 45721               NaN               NaN              NaN
# 45722          2.749608          2.110001        11.940002
#
#        Kdp_5x5_90th_qtil_0.1  Kdp_5x5_90th_qtil_0.3 Kdp_5x5_90th_qtil_0.5  \
# 0                   2.259997               2.889993              3.529999
# 1                        NaN                    NaN                   NaN
# 2                   1.557999               2.679996              3.199997
# 3                   1.480989               2.924994              3.519989
# 4                   6.635995               8.065994              9.849991
# 5                   2.224997               2.435001             10.159996
# 6                        NaN                    NaN                   NaN
# 7                   2.676993               3.771989              4.904991
# 8                   1.092998               1.409988              1.409988
# 9                   0.772992               1.618994              2.464996
# 10                  2.819992               3.860001              4.229996
# 11                  5.979990               9.941995             11.169998
# 12                  1.110001               2.119995              2.470001
# 13                  1.759994               2.819992              3.519989
# 14                  2.819992               3.575992              5.639999
# 15                  2.935995               3.749991              4.580002
# 16                       NaN                    NaN                   NaN
# 17                  1.903995               2.751996              5.279999
# 18                  1.527991               2.675992              2.819992
# 19                       NaN                    NaN                   NaN
# 20                  1.479990               2.572000              3.514992
# 21                       NaN                    NaN                   NaN
# 22                 -0.388001               3.692990              4.199997
# 23                  3.155997               9.467990             10.889992
# 24                  0.673991               1.549995              2.464996
# 25                  2.119995               2.439995              3.634995
# 26                       NaN                    NaN                   NaN
# 27                       NaN                    NaN                   NaN
# 28                 -1.765001              -0.355000              1.055000
# 29                  4.475998               6.740000              7.349991
# ...                      ...                    ...                   ...
# 45693               1.619992               2.819992              3.334992
# 45694               9.479996               9.479996              9.479996
# 45695               1.759994               2.470001              3.159988
# 45696               2.119995               2.819992              3.869995
# 45697               3.748990               4.426993              7.424996
# 45698              -4.764999               2.040001              2.869995
# 45699               0.735997               1.164995              1.759994
# 45700               1.409988               1.689993              1.759994
# 45701              -8.672003               5.645996              5.989990
# 45702              -1.515010               2.288998              5.144996
# 45703               0.349991               2.041995              3.014999
# 45704                    NaN                    NaN                   NaN
# 45705               4.017990               6.335999              6.599991
# 45706               1.199997               1.479996              1.759994
# 45707               1.729990               1.951994              3.500000
# 45708               2.920998               3.827995              4.929993
# 45709                    NaN                    NaN                   NaN
# 45710               0.709991               1.759994              1.939995
# 45711               1.511999               4.089993              4.889999
# 45712               1.409988               1.839996              2.470001
# 45713               2.819992               4.229996              5.059998
# 45714               2.991992               3.495996              4.000000
# 45715               5.001993               5.539999              6.690002
# 45716               0.880992               2.812996              3.334999
# 45717               1.619992               2.819992              3.334992
# 45718                    NaN                    NaN                   NaN
# 45719               2.841998               6.241998              8.379990
# 45720               1.637991               1.759994              2.114998
# 45721                    NaN                    NaN                   NaN
# 45722               2.533997               4.335996              5.279999
#
#        Kdp_5x5_90th_qtil_0.7  Kdp_5x5_90th_qtil_0.9     Expected
# 0                   4.150000               6.406000     5.080003
# 1                        NaN                    NaN     1.016001
# 2                   3.663989               3.879990     4.826003
# 3                   4.310998               4.876990     0.254000
# 4                  24.777994              31.659995     0.508000
# 5                  18.959991              25.619995     6.350004
# 6                        NaN                    NaN    13.208007
# 7                   5.289993               5.866992     2.286001
# 8                   1.759994               2.083995     5.080003
# 9                   3.310999               4.157001     0.254000
# 10                  7.000000               7.659988     1.270001
# 11                 13.287997              23.415991     0.030000
# 12                  3.949997               4.929993     1.524001
# 13                  4.539993               5.279999     1.778001
# 14                  6.778000               8.084000     2.032001
# 15                  7.991998              11.789997     1.016001
# 16                       NaN                    NaN     0.010000
# 17                 13.471991              19.833990     0.508000
# 18                  4.223993               7.109994     2.150001
# 19                       NaN                    NaN     0.762000
# 20                  4.103995               5.174999     2.540001
# 21                       NaN                    NaN     5.334003
# 22                  5.049992              11.042998    24.130013
# 23                 11.581995              13.513996     1.270001
# 24                  2.924994               3.669998     5.588003
# 25                  5.604996               7.154999     0.010000
# 26                       NaN                    NaN     0.254000
# 27                       NaN                    NaN     7.874004
# 28                  2.465001               3.875002     5.334003
# 29                  8.357993              10.525992     0.508000
# ...                      ...                    ...          ...
# 45693               4.264996               5.181993     0.762000
# 45694               9.479996               9.479996     0.508000
# 45695               4.159988               4.229996     1.016001
# 45696               4.229996               5.989990     1.016001
# 45697              10.330997              10.456992    23.750013
# 45698               3.749992               5.439995     0.254000
# 45699               2.116997               3.694995     0.762000
# 45700               2.119995               2.255994     0.508000
# 45701               6.541992               6.691995     2.794001
# 45702               5.812999               9.001999     1.778001
# 45703               4.720001               8.072992  2931.923600
# 45704                    NaN                    NaN     1.270001
# 45705               7.169995               8.963993     0.762000
# 45706               2.043997               2.328000     0.254000
# 45707               4.894994               8.256999     0.508000
# 45708               6.114998               8.800990     3.302002
# 45709                    NaN                    NaN     2.794001
# 45710               2.819992               3.438992     0.508000
# 45711               6.857999               9.447998     1.778001
# 45712               3.159988               3.729996     6.350004
# 45713               5.584991               7.644989     1.778001
# 45714               4.071997               4.143994     5.080003
# 45715               8.223993              10.361996     0.508000
# 45716               4.215996               5.199995     1.524001
# 45717               4.264996               5.181993     0.508000
# 45718                    NaN                    NaN     0.020000
# 45719               9.147989              11.143991     1.016001
# 45720               2.784993               4.004991     1.270001
# 45721                    NaN                    NaN    28.956015
# 45722               7.087997               8.951993     1.016001
#
# [45723 rows x 245 columns]

# %%
dfTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13765201 entries, 1 to 1180945
# Data columns (total 24 columns):
# Id                       int64
# minutes_past             int64
# radardist_km             float64
# Ref                      float64
# Ref_5x5_10th             float64
# Ref_5x5_50th             float64
# Ref_5x5_90th             float64
# RefComposite             float64
# RefComposite_5x5_10th    float64
# RefComposite_5x5_50th    float64
# RefComposite_5x5_90th    float64
# RhoHV                    float64
# RhoHV_5x5_10th           float64
# RhoHV_5x5_50th           float64
# RhoHV_5x5_90th           float64
# Zdr                      float64
# Zdr_5x5_10th             float64
# Zdr_5x5_50th             float64
# Zdr_5x5_90th             float64
# Kdp                      float64
# Kdp_5x5_10th             float64
# Kdp_5x5_50th             float64
# Kdp_5x5_90th             float64
# Expected                 float64
# dtypes: float64(22), int64(2)

# %%
value = range(1001)
p = np.zeros(1001)
for v in value:
    p[v] = (dfTrain['Expected'] >= v).mean()
    if (v % 100 == 0):
        print v, p[v]
# Out:
# 0 1.0
# 100 0.0195409783752
# 200 0.011997171086
# 300 0.0102092104095
# 400 0.0087429969434
# 500 0.00805862480319
# 600 0.0073740328903
# 700 0.00661208099239
# 800 0.00607990143635
# 900 0.00589122658652
# 1000 0.00588990795041

# %%
plt.figure()
plt.plot(range(1,1000), p[1:1000])
plt.show()

plt.figure()
plt.plot(range(10,150), p[10:150])
plt.show()

# %%
dfTrain = dfTrain.dropna()

# %%
dft = dfTrain[['Expected','Ref']]

# %%
value = range(151)
p = np.zeros(151)
for v in value:
    dt = dft[dft.Expected <= v]
    p[v] = dt['Expected'].corr(dt['Ref'])
    if (v % 10 == 0):
        print v, p[v]
# Out:
# 0 nan
# 10 0.277696760908
# 20 0.283114522361
# 30 0.274089913191
# 40 0.277586007381
# 50 0.264820863976
# 60 0.247332145903
# 70 0.241548837294
# 80 0.217655171538
# 90 0.202698949576
# 100 0.198369373044
# 110 0.185999593063
# 120 0.172493525247
# 130 0.161929881957
# 140 0.159557080863
# 150 0.153673563025

# %%
plt.figure()
plt.plot(value[3:], p[3:])
plt.show()

plt.figure()
plt.plot(value[10:150], p[10:150])
plt.show()

# %%
featuresSet="basic"
l_dfTrain = []
for i in xrange(1,17):
    print "Loading dataset basic_" + str(i) + 'sur16 into trainSets...'        
    l_dfTrain.append(pd.read_csv('./data/f_df_train_' + featuresSet + '_'+str(i)+'sur16.csv', index_col=0))
dfTrain = pd.concat(l_dfTrain)
# Out:
# Loading dataset basic_1sur16 into trainSets...
# Loading dataset basic_2sur16 into trainSets...
# Loading dataset basic_3sur16 into trainSets...
# Loading dataset basic_4sur16 into trainSets...
# Loading dataset basic_5sur16 into trainSets...
# Loading dataset basic_6sur16 into trainSets...
# Loading dataset basic_7sur16 into trainSets...
# Loading dataset basic_8sur16 into trainSets...
# Loading dataset basic_9sur16 into trainSets...
# Loading dataset basic_10sur16 into trainSets...
# Loading dataset basic_11sur16 into trainSets...
# Loading dataset basic_12sur16 into trainSets...
# Loading dataset basic_13sur16 into trainSets...
# Loading dataset basic_14sur16 into trainSets...
# Loading dataset basic_15sur16 into trainSets...
# Loading dataset basic_16sur16 into trainSets...

# %%
dfTrain.shape
# Out:
# (731571, 245)

# %%
(dfTrain.Ref < 0).sum()
# Out:
# 96535

# %%
dfTrain.dropna()[dfTrain.dropna().Expected > 100]
# Out:
#                Id  minutes_past  radardist_km   Ref  Ref_5x5_10th  \
# Id_index
# 221           221            20            12  30.0          22.0
# 221           221            26            12  31.0          31.0
# 221           221            29            12  41.0          39.0
# 221           221            32            12  49.0          44.5
# 675           675            20            12  30.0          22.0
# 675           675            26            12  31.0          31.0
# 675           675            29            12  41.0          39.0
# 675           675            32            12  49.0          44.5
# 1156         1156             4            10  30.0          25.0
# 1156         1156            10            10  28.5          25.5
# 1156         1156            16            10  32.5          27.5
# 1156         1156            22            10  31.0          31.0
# 1156         1156            28            10  35.0          30.5
# 1156         1156            34            10  34.0          28.5
# 1156         1156            39            10  34.0          29.0
# 1156         1156            45            10  33.0          32.5
# 1156         1156            53            10  35.5          28.0
# 1156         1156            59            10  37.0          33.0
# 1239         1239            23            12  29.0          28.0
# 1239         1239            27            12  30.0          27.0
# 1239         1239            30            12  22.0          23.0
# 1239         1239            34            12  22.5          19.0
# 1239         1239            38            12  24.5          18.5
# 1239         1239            42            12  19.5          17.0
# 1239         1239            46            12  11.5          11.0
# 1239         1239            50            12  18.0          12.0
# 1239         1239            54            12  15.5          13.5
# 1239         1239            58            12  19.5          14.0
# 2043         2043            20             5  13.0          13.0
# 2043         2043            29             5  22.0          18.0
# ...           ...           ...           ...   ...           ...
# 1179244   1179244             5            14  18.5          18.5
# 1179244   1179244             9            14  22.5          18.5
# 1179244   1179244            12            14  18.0          17.5
# 1179244   1179244            16            14  22.0          14.0
# 1179244   1179244            20            14  21.0          15.0
# 1179244   1179244            23            14  19.0          16.0
# 1179244   1179244            27            14  23.0          17.0
# 1179244   1179244            31            14  20.0          19.0
# 1179244   1179244            34            14  27.5          19.0
# 1179244   1179244            38            14  28.0          23.0
# 1179244   1179244            41            14  26.0          22.5
# 1179244   1179244            45            14  22.5          20.5
# 1179244   1179244            48            14  18.5          18.5
# 1179244   1179244            52            14  24.0          15.5
# 1179244   1179244            55            14  20.5          17.5
# 1179244   1179244            59            14  21.5          14.0
# 1180037   1180037            52            14  26.0          21.0
# 1180037   1180037            55            14  28.0          21.5
# 1180037   1180037            59            14  23.0          14.0
# 1180245   1180245            26            13  24.5          24.5
# 1180245   1180245            31            13  27.0          25.0
# 1179244      -2.470001     -0.699997      3.519989  115.00006
# 1179244      -1.410004      1.059998      6.679993  115.00006
# 1180037      -7.040009      2.119995      8.179993  166.37009
# 1180037      -3.169998      0.709991      4.580002  166.37009
# 1180037      -6.889999     -1.410004      7.379990  166.37009
# 1180245      -1.760010     -0.699997      3.519989  115.00006
# 1180245      -4.930008      0.709991      2.119995  115.00006
# 1180245      -1.410004      1.409988      2.119995  115.00006
# 1180245      -1.760010      0.000000      2.819992  115.00006
# 1180245      -0.710007      0.360001      1.059998  115.00006
# 1180245      -1.059998      0.000000      1.409988  115.00006
# 1180245      -1.059998      0.349991      2.119995  115.00006
# 1180619      -0.710007     -0.350006      3.169998  400.81220
# 1180857      -2.050003     -0.350006      3.169998  151.38408
# 1180857      -1.059998     -0.350006      0.709991  151.38408
# 1180857      -0.710007      0.349991      1.409988  151.38408
#
# [34786 rows x 24 columns]

# %%
# Ref = a * (Expected^b)
# Expected = broot (Ref / a)
# 


class marshallPalmerRegressor():
    def __init__(self, epsA=1e0, epsB=1e-1, nepoch=1):
        self.epsA = epsA
        self.epsB = epsB
        self.nepoch = nepoch
        self.a = 200.
        self.b = 0.625
    def fit(self,data, y):
        for t in xrange(self.nepoch):
            z = np.power(10, data['Ref']/10)
            za = z/self.a
            pred = np.power(za,self.b) * data['valid_time'] 
            data['pred'] = pred
            data['db'] = np.log(za) * pred
            l = data.groupby('Id').sum()['db']
            p = data.groupby('Id').sum()['pred']
            sign = np.zeros(len(p))
            sign -= (y > p)
            sign += (y <= p)
            if (self.epsA != 0):
                da = - (sign * p * self.b / self.a).mean()
                self.a -= da * self.epsA
            if (self.epsB != 0):
                db = (sign * l).mean()
                self.b -= db * self.epsB
            #p = self.predict(data)
            print t, np.abs(p - y).mean(), self.a, self.b
    def predict(self,data):
        za = np.power(10, data['Ref']/10) / self.a
        p = np.power(za, self.b) * data['valid_time']
        data['pred'] = p
        return data.groupby('Id').sum()['pred']

# %%
# %%time
dfTrain = pd.read_csv('./data/train.csv')
dfTrain['Id_index'] = dfTrain['Id']
dfTrain = dfTrain.set_index('Id_index')
dfTrain = dfTrain[['Id', 'Ref', 'minutes_past', 'Expected']]

dfTrain.drop(dfTrain.Expected < 100, inplace=True)
dfTrain.drop(dfTrain.Ref < 0, inplace=True)
dfTrain.dropna(inplace=True)

y = dfTrain.groupby("Id").mean()['Expected']

minutes_past = dfTrain['minutes_past']
valid_time = np.zeros_like(minutes_past)
seqId = -1
for n in xrange(len(minutes_past)):
    if (seqId != dfTrain['Id'].iloc[n]):
        seqId = dfTrain['Id'].iloc[n]
        valid_time[n] = minutes_past.iloc[n]
    else:
        valid_time[n] = minutes_past.iloc[n] - minutes_past.iloc[n-1]
valid_time[-1] = valid_time[-1] + 60 - np.sum(valid_time)
valid_time = valid_time / 60.
dfTrain['valid_time'] = valid_time
dfTrain.drop(['minutes_past'], inplace=True)
# Out:
# CPU times: user 6min 11s, sys: 3.86 s, total: 6min 15s
# Wall time: 6min 23s

# %%
model = marshallPalmerRegressor(epsA=0, epsB=5e-2, nepoch=10)
model.fit(dfTrain,y)
# Out:
# 0 23.522796116 200.0 0.462654250127
# 1 23.4417218282 200.0 0.515937874968
# 2 23.400650838 200.0 0.535190312359
# 3 23.3967114521 200.0 0.535686146513
# 4 23.3967092718 200.0 0.535607575826
# 5 23.396709246 200.0 0.535644114122
# 6 23.3967092356 200.0 0.535624760639
# 7 23.3967092355 200.0 0.535642441954
# 8 23.3967092352 200.0 0.535632427464
# 9 23.3967092343 200.0 0.535635734419

# %%
model.epsA = 1
model.epsB = 0
model.fit(dfTrain,y)
# Out:
# 0 23.3967092341 200.000386529 0.535635734419
# 1 23.3967090847 200.000772987 0.535635734419
# 2 23.3967089354 200.001159445 0.535635734419
# 3 23.396708786 200.001545901 0.535635734419
# 4 23.3967086367 200.001932357 0.535635734419
# 5 23.3967084873 200.002318811 0.535635734419
# 6 23.396708338 200.002705264 0.535635734419
# 7 23.3967081886 200.003091715 0.535635734419
# 8 23.3967080393 200.003478166 0.535635734419
# 9 23.3967078899 200.003864616 0.535635734419

# %%
model.epsA = 1e4
model.epsB = 0
model.fit(dfTrain,y)
# Out:
# 0 23.3805759328 282.153459949 0.558794512981
# 1 23.3805756476 282.203826958 0.558794512981
# 2 23.3805753986 282.252409264 0.558794512981
# 3 23.3805751659 282.299282435 0.558794512981
# 4 23.3805749563 282.342308694 0.558794512981
# 5 23.3805747732 282.384357545 0.558794512981
# 6 23.3805746018 282.423987254 0.558794512981
# 7 23.3805744505 282.460674457 0.558794512981
# 8 23.3805743182 282.495678292 0.558794512981
# 9 23.3805741978 282.529755105 0.558794512981

# %% [markdown]
# model.a = 250

# %%
dfTest = pd.read_csv('./data/test.csv')

minutes_past = dfTest['minutes_past']
valid_time = np.zeros_like(minutes_past)
seqId = -1
for n in xrange(len(minutes_past)):
    if (seqId != dfTest['Id'].iloc[n]):
        seqId = dfTest['Id'].iloc[n]
        valid_time[n] = minutes_past.iloc[n]
    else:
        valid_time[n] = minutes_past.iloc[n] - minutes_past.iloc[n-1]
valid_time[-1] = valid_time[-1] + 60 - np.sum(valid_time)
valid_time = valid_time / 60.
dfTest['valid_time'] = valid_time
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-bd6f9df3f45a> in <module>()
#      13 valid_time = valid_time / 60.
#      14 dfTest['valid_time'] = valid_time
# ---> 15 dfTest.drop(['minutes_past'], inplace=True)
#
# /usr/lib/python2.7/dist-packages/pandas/core/generic.pyc in drop(self, labels, axis, level, inplace, **kwargs)
#    1462                 new_axis = axis.drop(labels, level=level)
#    1463             else:
# -> 1464                 new_axis = axis.drop(labels)
#    1465             dropped = self.reindex(**{axis_name: new_axis})
#    1466             try:
#
# /usr/lib/python2.7/dist-packages/pandas/core/index.pyc in drop(self, labels)
#    1829         mask = indexer == -1
#    1830         if mask.any():
# -> 1831             raise ValueError('labels %s not contained in axis' % labels[mask])
#    1832         return self.delete(indexer)
#    1833
#
# ValueError: labels ['minutes_past'] not contained in axis

# %%
pred = model.predict(dfTest)

# %%
pred.fillna(0.0, inplace=True)

# %%
pred.to_csv('MarshallPalmer.csv')
